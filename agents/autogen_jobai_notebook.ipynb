# %% [markdown]
# ## Using Autogen to get you a Job
#
# Autogen allows for a multi-agent approach with knowledge.
#
# Let's use it here to build a team of recruiters and get you that job.
#
# Based on [this notebook](https://github.com/microsoft/autogen/blob/main/notebook/agentchat_teaching.ipynb).

# %% [markdown]
# ### Autogen Config

# %%
import autogen 

llm_config = {
    "timeout": 600,
    "cache_seed": 44,  # change the seed for different trials
    "config_list": autogen.config_list_from_json("config.json"),
    "temperature": 0,
}

# %% [markdown]
# ### Create Agents to help me develop
#
# The first default case is 2 agents: Assistant and User Proxy.

# %%
# create an AssistantAgent instance named "assistant"
coder_assistant = autogen.AssistantAgent(
    name="assistant",
    llm_config=llm_config,
    is_termination_msg=lambda x: True if "TERMINATE" in x.get("content") else False,
    system_message="You're the best software developer in the world. You will assess the requirement and think step by step. You continue to improve on the code until it meets the requirements.",
)

# create a UserProxyAgent instance named "user_proxy"
user_proxy = autogen.UserProxyAgent(
    name="user_proxy",
    human_input_mode="ALWAYS",
    is_termination_msg=lambda x: True if "TERMINATE" in x.get("content") else False,
    max_consecutive_auto_reply=10,
    code_execution_config={
        "work_dir": "work_dir",
        "use_docker": False,
    },
    llm_config=llm_config,
    system_message="Reply TERMINATE if the task has been solved at full satisfaction. Otherwise, reply CONTINUE, or the reason why the task is not solved yet.",
)

# initiate task
user_proxy.initiate_chat(
    coder_assistant, 
    message="""
Build a resume parser that can extract the necessary information from a resume to fill in a job application form.
""",
)
# Out:
# user_proxy (to assistant):
#
#
# Build a resume parser that can extract the necessary information from a resume to fill in a job application form.
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# Building a resume parser involves several steps, including text extraction, information categorization, and data mapping. Here's a step-by-step approach:
#
# 1. **Requirement Analysis**: Understand the necessary information that needs to be extracted from a resume. This typically includes name, contact information, skills, education, work experience, and certifications.
#
# 2. **Designing the Parser**: Design the parser to extract the required information. This involves deciding on the technology stack and the architecture of the application. Python is a good choice for this task due to its powerful libraries for text processing and machine learning.
#
# 3. **Text Extraction**: Use a library like PyPDF or PDFMiner for Python to extract text from the resume. If the resume is in a different format, like .docx, use an appropriate library such as python-docx.
#
# 4. **Information Categorization**: Use Natural Language Processing (NLP) techniques to categorize the extracted information. Libraries like NLTK or Spacy can be used for this purpose. Named Entity Recognition (NER) can be used to identify the candidate's name, organizations they've worked for, and other specific information.
#
# 5. **Data Mapping**: Map the extracted information to the fields in the job application form. This step might involve some manual coding, as the mapping will depend on the specific fields of the form.
#
# 6. **Testing**: Test the parser with different resumes and job application forms to ensure it works correctly. Make adjustments as necessary based on the test results.
#
# 7. **Improvement**: Use machine learning techniques to improve the accuracy of the parser. This could involve training a model on a dataset of resumes and job application forms.
#
# 8. **Deployment**: Once the parser is working satisfactorily, deploy it in the required environment.
#
# 9. **Maintenance and Updates**: Regularly update the parser to handle new resume formats and improve its accuracy. Also, maintain the parser by fixing any bugs or issues that arise.
#
# This is a high-level approach and the actual implementation might involve more detailed steps depending on the specific requirements and constraints of the project.
#
# --------------------------------------------------------------------------------
# user_proxy (to assistant):
#
# great, for now lets design the parser with the typical information you mentioned in 1.
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# Sure, let's design a basic resume parser. We'll use Python and its libraries for this task. Here's a high-level design:
#
# 1. **Import Necessary Libraries**: We'll need libraries for PDF and DOCX processing, NLP, and possibly machine learning. Some libraries we might use include PyPDF2 or PDFMiner, python-docx, NLTK or Spacy, and scikit-learn.
#
# ```python
# import PyPDF2
# import docx
# import nltk
# ```
#
# 2. **Text Extraction Function**: This function will take a file path as input and return the extracted text. It will need to handle both PDF and DOCX files.
#
# ```python
# def extract_text(file_path):
#     # Check file extension
#     if file_path.endswith('.pdf'):
#         # Use PyPDF2 or PDFMiner to extract text
#     elif file_path.endswith('.docx'):
#         # Use python-docx to extract text
#     else:
#         print("Unsupported file format")
#         return None
# ```
#
# 3. **Information Extraction Functions**: These functions will use NLP techniques to extract specific information from the text. For example, we might have a function to extract names, another to extract contact information, and so on.
#
# ```python
# def extract_name(text):
#     # Use NLP to extract name
#
# def extract_contact_info(text):
#     # Use NLP to extract contact info
#
# # And so on for other information
# ```
#
# 4. **Main Function**: This function will call the other functions to extract all the necessary information from a resume.
#
# ```python
# def parse_resume(file_path):
#     text = extract_text(file_path)
#     name = extract_name(text)
#     contact_info = extract_contact_info(text)
#     # And so on for other information
#     return {
#         'name': name,
#         'contact_info': contact_info,
#         # And so on for other information
#     }
# ```
#
# This is a basic design for the resume parser. The actual implementation will be more complex and will need to handle various edge cases. Also, the NLP and machine learning parts will require a good amount of fine-tuning to achieve satisfactory accuracy.
#
# --------------------------------------------------------------------------------
# user_proxy (to assistant):
#
# great, use the work_dir and write the code to a file
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# Sure, let's write the basic structure of the resume parser to a Python file. Here's how you can do it:
#
# ```python
# # Import necessary libraries
# import os
# import PyPDF2
# import docx
# import nltk
#
# # Text extraction function
# def extract_text(file_path):
#     if file_path.endswith('.pdf'):
#         # Use PyPDF2 or PDFMiner to extract text
#         pass
#     elif file_path.endswith('.docx'):
#         # Use python-docx to extract text
#         pass
#     else:
#         print("Unsupported file format")
#         return None
#
# # Information extraction functions
# def extract_name(text):
#     # Use NLP to extract name
#     pass
#
# def extract_contact_info(text):
#     # Use NLP to extract contact info
#     pass
#
# # Main function
# def parse_resume(file_path):
#     text = extract_text(file_path)
#     name = extract_name(text)
#     contact_info = extract_contact_info(text)
#     return {
#         'name': name,
#         'contact_info': contact_info,
#     }
#
# # Write to file
# with open(os.path.join('work_dir', 'resume_parser.py'), 'w') as file:
#     file.write(inspect.getsource(extract_text))
#     file.write(inspect.getsource(extract_name))
#     file.write(inspect.getsource(extract_contact_info))
#     file.write(inspect.getsource(parse_resume))
# ```
#
# This will create a Python file named `resume_parser.py` in the `work_dir` directory. The file will contain the basic structure of the resume parser. You can then fill in the details of the functions as needed.
#
# --------------------------------------------------------------------------------
# user_proxy (to assistant):
#
# ok, write the file. for now let's keep it simple and skip the NLP, but write the pypdf part of the code
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# Sure, let's write a simple version of the resume parser that can extract text from PDF files. Here's the code:
#
# ```python
# # Import necessary libraries
# import os
# import PyPDF2
#
# # Text extraction function
# def extract_text(file_path):
#     if file_path.endswith('.pdf'):
#         # Use PyPDF2 to extract text
#         pdf_file_obj = open(file_path, 'rb')
#         pdf_reader = PyPDF2.PdfFileReader(pdf_file_obj)
#         text = ''
#         for page_num in range(pdf_reader.numPages):
#             page_obj = pdf_reader.getPage(page_num)
#             text += page_obj.extractText()
#         pdf_file_obj.close()
#         return text
#     else:
#         print("Unsupported file format")
#         return None
#
# # Main function
# def parse_resume(file_path):
#     text = extract_text(file_path)
#     return {
#         'text': text,
#     }
#
# # Write to file
# with open(os.path.join('work_dir', 'resume_parser.py'), 'w') as file:
#     file.write("import os\n")
#     file.write("import PyPDF2\n\n")
#     file.write(inspect.getsource(extract_text))
#     file.write("\n")
#     file.write(inspect.getsource(parse_resume))
# ```
#
# This will create a Python file named `resume_parser.py` in the `work_dir` directory. The file will contain a simple resume parser that can extract text from PDF files. The parser doesn't do any information extraction yet, it just returns the raw text.
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 24
#      10 user_proxy = autogen.UserProxyAgent(
#      11     name="user_proxy",
#      12     human_input_mode="ALWAYS",
#    (...)
#      20     system_message="Reply TERMINATE if the task has been solved at full satisfaction. Otherwise, reply CONTINUE, or the reason why the task is not solved yet.",
#      21 )
#      23 # initiate task
# ---> 24 user_proxy.initiate_chat(
#      25     coder_assistant,
#      26     message="""
#      27 Build a resume parser that can extract the necessary information from a resume to fill in a job application form.
#      28 """,
#      29 )
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:698, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, **context)
#     696     agent.client_cache = cache
#     697 self._prepare_chat(recipient, clear_history)
# --> 698 self.send(self.generate_init_message(**context), recipient, silent=silent)
#     699 for agent in [self, recipient]:
#     700     agent.client_cache = agent.previous_cache
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:441, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     439 valid = self._append_oai_message(message, "assistant", recipient)
#     440 if valid:
# --> 441     recipient.receive(message, self, request_reply, silent)
#     442 else:
#     443     raise ValueError(
#     444         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     445     )
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:601, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     599 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     600 if reply is not None:
# --> 601     self.send(reply, sender, silent=silent)
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:441, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     439 valid = self._append_oai_message(message, "assistant", recipient)
#     440 if valid:
# --> 441     recipient.receive(message, self, request_reply, silent)
#     442 else:
#     443     raise ValueError(
#     444         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     445     )
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:601, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     599 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     600 if reply is not None:
# --> 601     self.send(reply, sender, silent=silent)
#
#     [... skipping similar frames: ConversableAgent.send at line 441 (5 times), ConversableAgent.receive at line 601 (4 times)]
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:601, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     599 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     600 if reply is not None:
# --> 601     self.send(reply, sender, silent=silent)
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:441, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     439 valid = self._append_oai_message(message, "assistant", recipient)
#     440 if valid:
# --> 441     recipient.receive(message, self, request_reply, silent)
#     442 else:
#     443     raise ValueError(
#     444         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     445     )
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:599, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     597 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     598     return
# --> 599 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     600 if reply is not None:
#     601     self.send(reply, sender, silent=silent)
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1298, in ConversableAgent.generate_reply(self, messages, sender, exclude)
#    1296     continue
#    1297 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 1298     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    1299     if final:
#    1300         return reply
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1058, in ConversableAgent.check_termination_and_human_reply(self, messages, sender, config)
#    1056 no_human_input_msg = ""
#    1057 if self.human_input_mode == "ALWAYS":
# -> 1058     reply = self.get_human_input(
#    1059         f"Provide feedback to {sender.name}. Press enter to skip and use auto-reply, or type 'exit' to end the conversation: "
#    1060     )
#    1061     no_human_input_msg = "NO HUMAN INPUT RECEIVED." if not reply else ""
#    1062     # if the human input is empty, and the message is a termination message, then we will terminate the conversation
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1405, in ConversableAgent.get_human_input(self, prompt)
#    1394 def get_human_input(self, prompt: str) -> str:
#    1395     """Get human input.
#    1396
#    1397     Override this method to customize the way to get human input.
#    (...)
#    1403         str: human input.
#    1404     """
# -> 1405     reply = input(prompt)
#    1406     return reply
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/ipykernel/kernelbase.py:1270, in Kernel.raw_input(self, prompt)
#    1268     msg = "raw_input was called, but this frontend does not support input requests."
#    1269     raise StdinNotImplementedError(msg)
# -> 1270 return self._input_request(
#    1271     str(prompt),
#    1272     self._parent_ident["shell"],
#    1273     self.get_parent("shell"),
#    1274     password=False,
#    1275 )
#
# File ~/miniconda3/envs/jobai/lib/python3.11/site-packages/ipykernel/kernelbase.py:1313, in Kernel._input_request(self, prompt, ident, parent, password)
#    1310 except KeyboardInterrupt:
#    1311     # re-raise KeyboardInterrupt, to truncate traceback
#    1312     msg = "Interrupted by user"
# -> 1313     raise KeyboardInterrupt(msg) from None
#    1314 except Exception:
#    1315     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
